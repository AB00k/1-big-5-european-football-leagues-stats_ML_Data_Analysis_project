# %% [markdown]
# # Project Title - Top 5 european football leagues analysis
# ![13273.jpg](attachment:13273.jpg)
#
# "The Top 5 European Football Leagues Analysis project uses data from Kaggle to examine the domestic football (soccer) leagues of the top 5 European countries. The data set does not include European competitions such as the UEFA Champions League and Europa League. The goal of this project is to analyze and understand various aspects of the domestic football leagues, including team performance, player statistics, and league trends."
#
# Domestic football leagues in Europe are structured in a pyramid-like system, where teams are grouped into different tiers based on their level of skill and competitiveness. At the top of the pyramid is the first tier, also known as the top flight or the top division, which is where the best teams in the country compete against each other.
#
# Below the top tier, there are usually one or two lower divisions, where teams that were relegated from the top tier, as well as teams that have not yet been promoted, compete against each other. The number of teams in each division varies from country to country, but it typically ranges from 20 to 24 teams.
#
# In addition to these domestic leagues, there are also international competitions, such as the UEFA Champions League and the UEFA Europa League, which allow teams from different countries to compete against each other.

# %% [markdown]
# ## Now I will talk about the top 5 leagues in Europe,
#
# ![Top-Six-Club-Badges-on-Football-Shirts-511ce17bb9149d1162b410444721caec.webp](attachment:Top-Six-Club-Badges-on-Football-Shirts-511ce17bb9149d1162b410444721caec.webp)
#
#
# ## The English Premier League:
#     Known for its high-paced and physical style of play, the Premier League is home to some of the most popular and successful clubs in the world, such as Manchester United, Liverpool, and Chelsea.

# %% [markdown]
# ![4BGb0M.jpg](attachment:4BGb0M.jpg)
#
#
# ## La Liga:
#     Spain's top league is home to some of the best teams in the world, such as Real Madrid and Barcelona. Known for its technical and possession-based style of play, La Liga is considered one of the best leagues in the world.

# %% [markdown]
# ![bundesliga_2016_wallpaper_by_jafarjeef_dae5azk-fullview.jpg](attachment:bundesliga_2016_wallpaper_by_jafarjeef_dae5azk-fullview.jpg)
#
#
# ## The Bundesliga:
#     Germany's top league is known for its high-intensity, fast-paced football and its emphasis on youth development. Clubs such as Bayern Munich and Borussia Dortmund have enjoyed great success both domestically and in Europe in recent years.

# %% [markdown]
# ![wp2011116.jpg](attachment:wp2011116.jpg)
#
#
# ## Serie A:
#     Italy's top league is known for its defensive and tactical approach to the game. It's home of the team Juventus, AC Milan, and Inter Milan and they are the most successful clubs in the league's history.

# %% [markdown]
# ![wp3097401.jpg](attachment:wp3097401.jpg)
#
#
# Ligue 1: France's top league is home to some of the best teams in Europe, such as Paris Saint-Germain and Olympique Lyon. The league is known for its attractive and attacking style of play.

# %% [markdown]
# ## Downloading the Dataset
#
# In this section, the dataset is downloaded from a Kaggle URL using the opendatasets library. The dataset is then extracted and saved to the local directory './big-5-european-football-leagues-stats'. The list of files within the dataset is then printed using the os library's listdir() function. Finally, the name of the project is defined as a string variable.
#
# ## The data is for 11 seasons of football(from 2010-2011 to 2020-2021 included)
#
# The columns contains stats of teams season by season and can be used to analyze performance of teams over the years.It consists of name of the team/club,games played,number of wins,number of losses,number of draws,points accumulated and other relevant football stats.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/datasets/jehanbhathena/big-5-european-football-leagues-stats'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in ".\big-5-european-football-leagues-stats" (use force=True to force download)

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
data_dir = './big-5-european-football-leagues-stats'

# %%
import os
os.listdir(data_dir)
# Out:
# ['Big 5 European football leagues teams stats.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "top-5-european-football-leagues-analysis"

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Updating notebook "abdulbasitab00k/top-5-european-football-leagues-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis
# 'https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# In this cell, the pandas library is imported and used to read the 'Big 5 European football leagues teams stats.csv' file into a dataframe called 'teams_df'. The head() function is then used to print the first 5 rows of the dataframe. The shape and columns of the dataframe are also printed. It is noted that some of the columns, such as 'goals_for', 'games_starts', 'games_complete', and 'unused_subs', are deemed unnecessary and have a high percentage of null values. The drop() function is used to remove these columns from the dataframe. Null values in the dataframe are also replaced with zeros using the fillna() function. The head() function is used again to print the first 7 rows of the modified dataframe.

# %%
import pandas as pd
import numpy as np

# %%
teams_df = pd.read_csv(data_dir + '/Big 5 European football leagues teams stats.csv')

# %%
teams_df.head(5)
# Out:
#       competition     season  rank            squad  games  wins  draws  \
# 0  Premier League  2010-2011     1   Manchester Utd     38    23     11
# 1  Premier League  2010-2011     2          Chelsea     38    21      8
# 2  Premier League  2010-2011     3  Manchester City     38    21      8
# 3  Premier League  2010-2011     4          Arsenal     38    19     11
# 4  Premier League  2010-2011     5        Tottenham     38    16     14
#
#    losses  goals_for  goals_against  ...  cards_red  shots_on_target_against  \
# 0       4         78             37  ...        3.0                      139
# 1       9         69             33  ...        1.0                      148
# 2       9         60             33  ...        5.0                      153
# 3       8         72             43  ...        6.0                      150
# 4       8         55             46  ...        2.0                      183
#
#   saves  clean_sheets  shots_on_target  games_starts  games_complete  \
# 0   102            15              218           418             NaN
# 1   115            15              241           418             NaN
# 2   120            18              182           418             NaN
# 3   106            13              243           418             NaN
# 4   137             8              202           418             NaN
#
#    games_subs  unused_subs  points_per_match
# 0          99          NaN              2.11
# 1         107          NaN              1.87
# 2         102          NaN              1.87
# 3         107          NaN              1.79
# 4          96          NaN              1.63
#
# [5 rows x 28 columns]

# %%
teams_df.shape
# Out:
# (1078, 28)

# %%
teams_df.columns
# Out:
# Index(['competition', 'season', 'rank', 'squad', 'games', 'wins', 'draws',
#        'losses', 'goals_for', 'goals_against', 'goal_diff', 'points', 'notes',
#        'players_used', 'assists', 'pens_made', 'pens_att', 'cards_yellow',
#        'cards_red', 'shots_on_target_against', 'saves', 'clean_sheets',
#        'shots_on_target', 'games_starts', 'games_complete', 'games_subs',
#        'unused_subs', 'points_per_match'],
#       dtype='object')

# %% [markdown]
# Here I can see soe useless columns according to initial approach I have in my mind so, we can just simply drop those columns. Using pandas .drop functiion

# %%
teams_df.drop(['games_starts','games_complete','unused_subs'], axis=1, inplace=True)

# %%
teams_df.head(7)
# Out:
#       competition     season  rank            squad  games  wins  draws  \
# 0  Premier League  2010-2011     1   Manchester Utd     38    23     11
# 1  Premier League  2010-2011     2          Chelsea     38    21      8
# 2  Premier League  2010-2011     3  Manchester City     38    21      8
# 3  Premier League  2010-2011     4          Arsenal     38    19     11
# 4  Premier League  2010-2011     5        Tottenham     38    16     14
# 5  Premier League  2010-2011     6        Liverpool     38    17      7
# 6  Premier League  2010-2011     7          Everton     38    13     15
#
#    losses  goals_for  goals_against  ...  pens_made  pens_att cards_yellow  \
# 0       4         78             37  ...          3         5         56.0
# 1       9         69             33  ...          6         8         59.0
# 2       9         60             33  ...          8         9         71.0
# 3       8         72             43  ...          4         7         65.0
# 4       8         55             46  ...          5         5         50.0
# 5      14         59             44  ...          7         8         63.0
# 6      10         51             45  ...          3         4         56.0
#
#    cards_red  shots_on_target_against  saves  clean_sheets  shots_on_target  \
# 0        3.0                      139    102            15              218
# 1        1.0                      148    115            15              241
# 2        5.0                      153    120            18              182
# 3        6.0                      150    106            13              243
# 4        2.0                      183    137             8              202
# 5        2.0                      149    105            14              204
# 6        5.0                      153    108             9              192
#
#    games_subs  points_per_match
# 0          99              2.11
# 1         107              1.87
# 2         102              1.87
# 3         107              1.79
# 4          96              1.63
# 5          93              1.53
# 6         106              1.42
#
# [7 rows x 25 columns]

# %%
teams_df.drop('notes', axis=1, inplace=True)

# %%
null_columns = teams_df.columns[teams_df.isnull().any()]
null_columns
# Out:
# Index(['cards_yellow', 'cards_red'], dtype='object')

# %% [markdown]
# There are not many columns with null values so I just replace those values values with 0 .

# %%
teams_df.loc[:, ['cards_yellow', 'cards_red']].fillna(0, inplace=True)

# %%
teams_df.columns
# Out:
# Index(['competition', 'season', 'rank', 'squad', 'games', 'wins', 'draws',
#        'losses', 'goals_for', 'goals_against', 'goal_diff', 'points',
#        'players_used', 'assists', 'pens_made', 'pens_att', 'cards_yellow',
#        'cards_red', 'shots_on_target_against', 'saves', 'clean_sheets',
#        'shots_on_target', 'games_subs', 'points_per_match'],
#       dtype='object')

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "abdulbasitab00k/top-5-european-football-leagues-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis
# 'https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis'

# %% [markdown]
# ## Exploratory Analysis and Visualization
# In this cell, the seaborn library is installed using the !pip install command. The seaborn and matplotlib libraries are then imported, and the matplotlib library is used to set the default style for plots. The '%matplotlib inline' magic command is used to display plots within the Jupyter Notebook. The teams_df dataframe is then grouped by competition and season, and the mean of the points column is calculated and stored in a new dataframe called 'points_df'. The head() function is used to print the first 5 rows of the points_df dataframe. A barplot is then created using the seaborn library's barplot() function, with the x-axis representing the competition and the y-axis representing the mean points. The plot is displayed using the show() function from the matplotlib library.

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\abdulbasit\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **TODO** - let's find out those years or number of seasons about those we have data inside data frame and names of those 5 leagues we have been talking about

# %%
teams_df.season.unique()
#len(teams_df.season.unique())
# Out:
# array(['2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015',
#        '2015-2016', '2016-2017', '2017-2018', '2018-2019', '2019-2020',
#        '2020-2021'], dtype=object)

# %%
leagues_names = teams_df.competition.unique()
leagues_names
# Out:
# array(['Premier League', 'Ligue 1', 'Fußball-Bundesliga', 'Serie A',
#        'La Liga'], dtype=object)

# %% [markdown]
# ![2F9MYAA-2.jpg](attachment:2F9MYAA-2.jpg)
#
# **TODO** - Let's create a new data frame that has information about the teams who have won thier respective leagues during seasons 2010-2011 to 2020-2021 ( both inclusive )

# %%
winners = teams_df[teams_df['rank'] == 1]
winners
# Out:
#              competition     season  rank            squad  games  wins  \
# 0         Premier League  2010-2011     1   Manchester Utd     38    23
# 20        Premier League  2011-2012     1  Manchester City     38    28
# 40        Premier League  2012-2013     1   Manchester Utd     38    28
# 60        Premier League  2013-2014     1  Manchester City     38    27
# 80        Premier League  2014-2015     1          Chelsea     38    26
# 100       Premier League  2015-2016     1   Leicester City     38    23
# 120       Premier League  2016-2017     1          Chelsea     38    30
# 140       Premier League  2017-2018     1  Manchester City     38    32
# 160       Premier League  2018-2019     1  Manchester City     38    32
# 180       Premier League  2019-2020     1        Liverpool     38    32
# 200       Premier League  2020-2021     1  Manchester City     38    27
# 220              Ligue 1  2010-2011     1            Lille     38    21
# 240              Ligue 1  2011-2012     1      Montpellier     38    25
# 260              Ligue 1  2012-2013     1        Paris S-G     38    25
# 280              Ligue 1  2013-2014     1        Paris S-G     38    27
# 300              Ligue 1  2014-2015     1        Paris S-G     38    24
# 320              Ligue 1  2015-2016     1        Paris S-G     38    30
# 340              Ligue 1  2016-2017     1           Monaco     38    30
# 360              Ligue 1  2017-2018     1        Paris S-G     38    29
# 380              Ligue 1  2018-2019     1        Paris S-G     38    29
# 400              Ligue 1  2019-2020     1        Paris S-G     27    22
# 420              Ligue 1  2020-2021     1            Lille     38    24
# 440   Fußball-Bundesliga  2010-2011     1         Dortmund     34    23
# 458   Fußball-Bundesliga  2011-2012     1         Dortmund     34    25
# 476   Fußball-Bundesliga  2012-2013     1    Bayern Munich     34    29
# 494   Fußball-Bundesliga  2013-2014     1    Bayern Munich     34    29
# 512   Fußball-Bundesliga  2014-2015     1    Bayern Munich     34    25
# 530   Fußball-Bundesliga  2015-2016     1    Bayern Munich     34    28
# 548   Fußball-Bundesliga  2016-2017     1    Bayern Munich     34    25
# 566   Fußball-Bundesliga  2017-2018     1    Bayern Munich     34    27
# 584   Fußball-Bundesliga  2018-2019     1    Bayern Munich     34    24
# 602   Fußball-Bundesliga  2019-2020     1    Bayern Munich     34    26
# 620   Fußball-Bundesliga  2020-2021     1    Bayern Munich     34    24
# 638              Serie A  2010-2011     1            Milan     38    24
# 658              Serie A  2011-2012     1         Juventus     38    23
# 678              Serie A  2012-2013     1         Juventus     38    27
# 698              Serie A  2013-2014     1         Juventus     38    33
# 718              Serie A  2014-2015     1         Juventus     38    26
# 738              Serie A  2015-2016     1         Juventus     38    29
# 758              Serie A  2016-2017     1         Juventus     38    29
# 778              Serie A  2017-2018     1         Juventus     38    30
# 798              Serie A  2018-2019     1         Juventus     38    28
# 818              Serie A  2019-2020     1         Juventus     38    26
# 838              Serie A  2020-2021     1            Inter     38    28
# 858              La Liga  2010-2011     1        Barcelona     38    30
# 878              La Liga  2011-2012     1      Real Madrid     38    32
# 898              La Liga  2012-2013     1        Barcelona     38    32
# 918              La Liga  2013-2014     1  Atlético Madrid     38    28
# 938              La Liga  2014-2015     1        Barcelona     38    30
# 958              La Liga  2015-2016     1        Barcelona     38    29
# 978              La Liga  2016-2017     1      Real Madrid     38    29
# 998              La Liga  2017-2018     1        Barcelona     38    28
# 1018             La Liga  2018-2019     1        Barcelona     38    26
# 1038             La Liga  2019-2020     1      Real Madrid     38    26
# 1058             La Liga  2020-2021     1  Atlético Madrid     38    26
#
#       draws  losses  goals_for  goals_against  ...  pens_made  pens_att  \
# 0        11       4         78             37  ...          3         5
# 20        5       5         93             29  ...          7         8
# 40        5       5         86             43  ...          4         7
# 60        5       6        102             37  ...          6         7
# 80        9       3         73             32  ...          4         5
# 100      12       3         68             36  ...         10        13
# 120       3       5         85             33  ...          2         4
# 140       4       2        106             27  ...          6         8
# 160       2       4         95             23  ...          3         4
# 180       3       3         85             33  ...          5         5
# 200       5       6         83             32  ...          5         9
# 220      13       4         68             36  ...          2         4
# 240       7       6         68             34  ...          7        10
# 260       8       5         69             23  ...          4         4
# 280       8       3         84             23  ...          9        10
# 300      11       3         83             36  ...         13        14
# 320       6       2        102             19  ...          6         8
# 340       5       3        107             31  ...         11        11
# 360       6       3        108             29  ...          7         9
# 380       4       5        105             35  ...         10        12
# 400       2       3         75             24  ...          6         8
# 420      11       3         64             23  ...          5         5
# 440       6       5         67             22  ...          0         3
# 458       6       3         80             25  ...          1         1
# 476       4       1         98             18  ...          4         5
# 494       3       2         94             23  ...          5         7
# 512       4       5         80             18  ...          6         6
# 530       4       2         80             17  ...          8         9
# 548       7       2         89             22  ...          5         5
# 566       3       4         92             28  ...          6         8
# 584       6       4         88             32  ...          3         4
# 602       4       4        100             32  ...          6         6
# 620       6       4         99             44  ...          9        10
# 638      10       4         65             24  ...          5         6
# 658      15       0         68             20  ...          2         4
# 678       6       5         71             24  ...          8        11
# 698       3       2         80             23  ...          4         4
# 718       9       3         72             24  ...          6         9
# 738       4       5         75             20  ...          9         9
# 758       4       5         77             27  ...          3         3
# 778       5       3         86             24  ...          4         8
# 798       6       4         70             30  ...          7         8
# 818       5       7         76             43  ...         13        14
# 838       7       3         89             35  ...          8         9
# 858       6       2         95             21  ...          5         5
# 878       4       2        121             32  ...         12        13
# 898       4       2        115             40  ...          4         5
# 918       6       4         77             26  ...          6        10
# 938       4       4        110             21  ...          6         7
# 958       4       5        112             29  ...         11        18
# 978       6       3        106             41  ...          6         8
# 998       9       1         99             29  ...          3         5
# 1018      9       3         90             36  ...          8         9
# 1038      9       3         70             25  ...         11        11
# 1058      8       4         67             25  ...          5         7
#
#       cards_yellow  cards_red  shots_on_target_against  saves  clean_sheets  \
# 0             56.0        3.0                      139    102            15
# 20            51.0        5.0                      133    104            17
# 40            57.0        1.0                      152    109            13
# 60             0.0        0.0                      126     89            16
# 80             0.0        0.0                      121     89            17
# 100            0.0        0.0                      136    100            15
# 120            0.0        0.0                      105     72            16
# 140            NaN        NaN                       82     56            18
# 160           44.0        1.0                       76     57            20
# 180           38.0        1.0                      107     75            15
# 200           46.0        2.0                       89     65            19
# 220           53.0        1.0                      142    106            11
# 240           68.0        7.0                      129     95            17
# 260           73.0        9.0                      123    101            23
# 280            0.0        0.0                      108     85            20
# 300            0.0        0.0                      114     78            13
# 320            0.0        0.0                      114     95            22
# 340            0.0        1.0                      118     89            17
# 360            NaN        NaN                      122     96            18
# 380           64.0        4.0                      124     98            17
# 400           50.0        1.0                       82     57            14
# 420           68.0        2.0                      107     86            21
# 440           38.0        1.0                      125    103            14
# 458           34.0        2.0                      108     83            15
# 476           36.0        1.0                       98     80            21
# 494            0.0        0.0                      116     93            17
# 512            0.0        0.0                       99     81            22
# 530            0.0        0.0                       84     67            20
# 548            0.0        0.0                      100     78            17
# 566            NaN        NaN                       93     69            16
# 584           42.0        2.0                       71     45            12
# 602           54.0        3.0                      114     86            15
# 620           44.0        3.0                      130     85             9
# 638           62.0        5.0                      135    111            20
# 658           68.0        4.0                      106     86            21
# 678           77.0        1.0                      110     86            19
# 698            0.0        0.0                      123    100            22
# 718            0.0        0.0                      103     79            19
# 738            0.0        0.0                       94     74            22
# 758            0.0        0.0                      108     81            18
# 778            NaN        NaN                       94     73            22
# 798           76.0        4.0                      107     79            16
# 818           87.0        3.0                      152    118            12
# 838           61.0        2.0                      112     82            14
# 858           72.0        2.0                      116     95            19
# 878           90.0        5.0                      134    102            14
# 898           57.0        2.0                      117     77            10
# 918            0.0        0.0                      100     74            20
# 938            0.0        0.0                       91     70            23
# 958            0.0        0.0                      124     95            18
# 978           76.0        2.0                      143    105            10
# 998           67.0        2.0                      136    109            19
# 1018          76.0        2.0                      129     96            17
# 1038          82.0        4.0                      108     84            19
# 1058         100.0        0.0                      120     97            18
#
#       shots_on_target  games_subs  points_per_match
# 0                 218          99              2.11
# 20                262         110              2.34
# 40                243         100              2.34
# 60                239         108              2.26
# 80                209         113              2.29
# 100               179         109              2.13
# 120               205         114              2.45
# 140               255         106              2.63
# 160               249         108              2.58
# 180               222         127              2.61
# 200               213          77              2.26
# 220               206         110              2.00
# 240               245         102              2.16
# 260               244         108              2.18
# 280               232         104              2.34
# 300               223         101              2.18
# 320               249         111              2.53
# 340               249         112              2.50
# 360               249         103              2.45
# 380               200         109              2.39
# 400               185          79              2.52
# 420               174         169              2.18
# 440               229         100              2.21
# 458               214         100              2.38
# 476               264          94              2.68
# 494               290          97              2.65
# 512               251          98              2.32
# 530               261          95              2.59
# 548               230          99              2.41
# 566               222         102              2.47
# 584               246         102              2.29
# 602               241         104              2.41
# 620               220         137              2.29
# 638               234          96              2.16
# 658               264         114              2.21
# 678               265         113              2.29
# 698               243         110              2.68
# 718               221         108              2.29
# 738               213         111              2.39
# 758               211         113              2.39
# 778               201         111              2.50
# 798               193         102              2.37
# 818               222         127              2.18
# 838               197         162              2.39
# 858               286         112              2.53
# 878               311         114              2.63
# 898               275         111              2.63
# 918               212         105              2.37
# 938               291         107              2.47
# 958               269          90              2.39
# 978               265         111              2.45
# 998               264         111              2.45
# 1018              243         112              2.29
# 1038              222         120              2.29
# 1058              179         148              2.26
#
# [55 rows x 24 columns]

# %% [markdown]
# **TODO** - plot a graph to show Number of Times Each Team Won the League

# %%
winners['squad'].value_counts().plot(kind='bar', x='squad', y='count', title='Number of Times Each Team Won the League')
# Out:
# <AxesSubplot: title={'center': 'Number of Times Each Team Won the League'}>

# %% [markdown]
# Above graph shows the top teams those who have won leagues in each of the season we have data in our data frame and on x-axis we have name of each teams who wins league tittle in any of 11 seasons and on y-axis we have count of league titles each team have won during the past 11 seasons. This give us a lot of information like it shows us teams who dominated thier leagues in past 11 years and on the other hand it shows us that if a like in our case juventus and bayern have been dominating their leagues very much so it shows us how less competative their leagues are

# %% [markdown]
# **TODO** - Now let's plot a graph to check how many different league winners a single league has had during the years this will tell us how competative a cometition is

# %%
winner_counts = winners.groupby('competition')['squad'].nunique().reset_index()

# Plot the counts as a bar chart
winner_counts.plot(kind='bar', x='competition', y='squad', title='Number of Winners in Each League')
# Out:
# <AxesSubplot: title={'center': 'Number of Unique Winners in Each League'}, xlabel='competition'>

# %% [markdown]
# So, as we have discussed in our previous analysis (graph) that if a team has only one winner who wins 90% of the times it may be because of the the league those teams play in are very much less competative if a league have more teams as winners so that it may mean that the league is more competative as many different teams as competeting for the title. Above graph shows how many different teams have won the title in recent seasons on x-axis we have leagues and on y-axis we have number of winners in recent 11 seasons and it shows that premier league is the most competaive team followed by laliga

# %%
winners.columns
# Out:
# Index(['competition', 'season', 'rank', 'squad', 'games', 'wins', 'draws',
#        'losses', 'goals_for', 'goals_against', 'goal_diff', 'points',
#        'players_used', 'assists', 'pens_made', 'pens_att', 'cards_yellow',
#        'cards_red', 'shots_on_target_against', 'saves', 'clean_sheets',
#        'shots_on_target', 'games_subs', 'points_per_match'],
#       dtype='object')

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %% [markdown]
# **TODO** - Let's check out different information about data frame like null values inside it and and d type of all the columns to better understanding of all our data set

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   competition              1078 non-null   object
#  1   season                   1078 non-null   object
#  2   rank                     1078 non-null   int64
#  3   squad                    1078 non-null   object
#  4   games                    1078 non-null   int64
#  5   wins                     1078 non-null   int64
#  6   draws                    1078 non-null   int64
#  7   losses                   1078 non-null   int64
#  8   goals_for                1078 non-null   int64
#  9   goals_against            1078 non-null   int64
#  10  goal_diff                1078 non-null   int64
#  11  points                   1078 non-null   int64
#  12  players_used             1078 non-null   int64
#  13  assists                  1078 non-null   int64
#  14  pens_made                1078 non-null   int64
#  15  pens_att                 1078 non-null   int64
#  16  cards_yellow             985 non-null    float64
#  17  cards_red                985 non-null    float64
#  18  shots_on_target_against  1078 non-null   int64
#  19  saves                    1078 non-null   int64
#  20  clean_sheets             1078 non-null   int64
#  21  shots_on_target          1078 non-null   int64
#  22  games_subs               1078 non-null   int64
#  23  points_per_match         1078 non-null   float64
# dtypes: float64(3), int64(18), object(3)
# memory usage: 202.2+ KB

# %%
teams_df.describe()
# Out:
#               rank        games         wins        draws       losses  \
# count  1078.000000  1078.000000  1078.000000  1078.000000  1078.000000
# mean     10.316327    37.077922    13.867347     9.343228    13.867347
# std       5.680370     1.996621     5.858596     2.990701     5.363658
# min       1.000000    27.000000     2.000000     2.000000     0.000000
# 25%       5.000000    38.000000    10.000000     7.000000    10.000000
# 50%      10.000000    38.000000    12.000000     9.000000    14.000000
# 75%      15.000000    38.000000    17.000000    11.000000    18.000000
# max      20.000000    38.000000    33.000000    19.000000    29.000000
#
#          goals_for  goals_against    goal_diff       points  players_used  \
# count  1078.000000    1078.000000  1078.000000  1078.000000   1078.000000
# mean     50.611317      50.611317     0.000000    50.913729     27.867347
# std      16.774271      12.677565    25.632355    16.706516      3.277909
# min      20.000000      17.000000   -61.000000    13.000000     19.000000
# 25%      39.000000      42.000000   -17.000000    40.000000     25.000000
# 50%      47.000000      51.000000    -5.000000    47.000000     28.000000
# 75%      59.000000      58.750000    13.750000    61.000000     30.000000
# max     121.000000      94.000000    89.000000   102.000000     42.000000
#
#        ...    pens_made     pens_att  cards_yellow   cards_red  \
# count  ...  1078.000000  1078.000000    985.000000  985.000000
# mean   ...     4.314471     5.545455     48.448731    2.728934
# std    ...     2.495380     2.904751     40.132120    2.703247
# min    ...     0.000000     0.000000      0.000000    0.000000
# 25%    ...     3.000000     3.000000      0.000000    0.000000
# 50%    ...     4.000000     5.000000     59.000000    2.000000
# 75%    ...     6.000000     7.000000     79.000000    4.000000
# max    ...    15.000000    20.000000    150.000000   12.000000
#
#        shots_on_target_against        saves  clean_sheets  shots_on_target  \
# count              1078.000000  1078.000000   1078.000000      1078.000000
# mean                160.691095   112.125232     10.269944       164.905380
# std                  31.489075    22.682912      3.890140        40.260807
# min                  71.000000    45.000000      2.000000        77.000000
# 25%                 139.000000    97.000000      8.000000       137.000000
# 50%                 162.000000   111.000000     10.000000       157.000000
# 75%                 180.750000   126.000000     13.000000       186.000000
# max                 271.000000   199.000000     24.000000       318.000000
#
#         games_subs  points_per_match
# count  1078.000000       1078.000000
# mean    109.913729          1.373302
# std      16.508769          0.443553
# min      71.000000          0.420000
# 25%     101.000000          1.080000
# 50%     109.000000          1.260000
# 75%     113.000000          1.630000
# max     189.000000          2.680000
#
# [8 rows x 21 columns]

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "abdulbasitab00k/top-5-european-football-leagues-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis
# 'https://jovian.ai/abdulbasitab00k/top-5-european-football-leagues-analysis'

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# #### Q1: TODO - Which are the top 10 teams with the best offensive performance among the league-winning teams over the last 11 years, when sorted on the basis of their offensive performance?

# %%
top_offensive_teams = winners.sort_values(by=['goals_for','shots_on_target','goal_diff','pens_made'],ascending=[False,False,False,True]).head(10).reset_index()
top_offensive = top_offensive_teams.loc[:,['squad','season','goals_for','shots_on_target','goal_diff','pens_made']].set_index(['squad','season'])

top_offensive.plot(kind='bar', stacked=False)
# Out:
# <AxesSubplot: xlabel='squad,season'>

# %% [markdown]
# as the question says we hve to find out top teams not form single league but from all these leagues so we decided some columns that involes in offensive columns and then take top ten out of them and plot them into the graph

# %% [markdown]
# #### Q2: TODO - Which are the top teams with the best defensive performance among the league-winning teams over the last 11 years, when sorted on the basis of their defensive performance?

# %%
top_defensive_teams = winners.sort_values(by=['clean_sheets','goals_against','shots_on_target_against','pens_att','saves'],ascending=[False,True,True,True,False]).head(10).reset_index()
top_defensive = top_defensive_teams.loc[:,['squad','season','clean_sheets','goals_against','shots_on_target_against','pens_att','saves']].set_index(['squad','season'])

top_defensive.plot(kind='barh', stacked=True)
# Out:
# <AxesSubplot: ylabel='squad,season'>

# %% [markdown]
# This question ask us to filter out top teams with the best defensive recods so we have approached this question same way as the previous one

# %% [markdown]
# #### Q3: TODO - Which are the top 10 squads in terms of overall performance over the last 11 years, when sorted on the basis of their overall performance, and visualized in a graph?

# %%
# let's create two columns to track their defensive and offensive and then finally overall rating columns we have to be carefull
# we can't find mean of all values of defensive df and offnsive df because some stats are better when they're less in value like 
# penalties conceeded in defensive track. W'll work with winners only as we can't even add a team to top ten if they have nevver
# won their respective league even if they hve better recods in offensive or defensive way
winners['defensive_recod'] = winners[['clean_sheets','saves']].mean(axis=1)
winners['offensive_recod'] = winners[['goals_for','shots_on_target','goal_diff','pens_made']].mean(axis=1)
# Out:
# C:\Users\ABDULBASIT\AppData\Local\Temp\ipykernel_7548\651773545.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winners['defensive_recod'] = winners[['clean_sheets','saves']].mean(axis=1)
# C:\Users\ABDULBASIT\AppData\Local\Temp\ipykernel_7548\651773545.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winners['offensive_recod'] = winners[['goals_for','shots_on_target','goal_diff','pens_made']].mean(axis=1)

# %%
winners['overall_ratings'] = winners[['points','wins','goals_for','points_per_match','defensive_recod','offensive_recod']].mean(axis=1)
# Out:
# C:\Users\ABDULBASIT\AppData\Local\Temp\ipykernel_7548\1996556738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winners['overall_ratings'] = winners[['points','wins','goals_for','points_per_match','defensive_recod','offensive_recod']].mean(axis=1)

# %%
top_squads = winners.sort_values('overall_ratings').head(10)

# %%
top_ = top_squads.loc[:,['squad','season','overall_ratings','offensive_recod','defensive_recod']].set_index(['squad','season'])

top_.plot(kind='bar', stacked=False)
# Out:
# <AxesSubplot: xlabel='squad,season'>

# %% [markdown]
# to decide the top teams we have to consider thier performance in each way like offensive and defensive combined and have to consider their titles that those teams have won so I have created a new column by taking mean value of multiplle columns like offensive and defensive and goals etc.

# %% [markdown]
# #### Q4: TODO - Which teams rank among the top in terms of offensive, defensive, and overall performance over the last 11 years, when combining the top performers in each category?

# %%
data = pd.concat([top_squads,top_defensive_teams,top_offensive_teams])

# %%
data.shape
# Out:
# (30, 28)

# %%
data_df = data.drop_duplicates(subset="squad")
data_df.shape
# Out:
# (12, 28)

# %% [markdown]
# Question says that we have to create a new data frame by combining all those squads we have created previously on the basis of their offensive and defensive and overall ratings

# %% [markdown]
# #### Q5: TODO - How do the ranks of each team in the data frame vary across seasons, as illustrated in a heat map for each team in each season?

# %%
top_teams = data_df.squad.tolist()
top_teams_df = teams_df.loc[teams_df["squad"].isin(top_teams)]

# %%
df_pivot = top_teams_df.pivot("squad", "season", "rank")
sns.heatmap(df_pivot, cmap='coolwarm')

plt.title("Team Rank by Season")
plt.xlabel("Season")
plt.ylabel("Team")
# Out:
# C:\Users\ABDULBASIT\AppData\Local\Temp\ipykernel_7548\1451615846.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = top_teams_df.pivot("squad", "season", "rank")
# Text(79.22222222222221, 0.5, 'Team')

# %% [markdown]
# Now we have to show the rankings of all those teams we have in that previously combined data frame ( most recent question ) in all those seasons we have data about and plot a graph to show to thir ranking in their recoective league in each of the 11 seasons

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "abdulbasitab00k/zerotopandas-course-project" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/abdulbasitab00k/zerotopandas-course-project
# 'https://jovian.ai/abdulbasitab00k/zerotopandas-course-project'

# %% [markdown]
# # Summary and Conclusion & References and Future Work
#
# # Summary:
#
# 1- The data set includes information about the top 5 European football leagues from 2010-2011 to 2020-2021.
#
# 2- The data frame was cleaned using different approaches and null values were replaced with zeros.
#
# 3- Some basic statistics and visualizations were generated to understand the distribution of various metrics among the teams.
#
# 4- The top teams in terms of offensive, defensive, and overall performance over the last 11 years were identified and compared.
#
# 5- A heat map was created to visualize the ranks of each team across seasons.
#
# # Possible conclusions based on the analysis:
#
# 1- The distribution of metrics such as wins, goals scored, and points varies significantly among the teams.
#
# 2- There are some teams that consistently perform well in all categories, while others may excel in some areas but struggle in others.
#
# 3- For some leagues the rankings of teams can change significantly from season to season, as illustrated by the heat map.
#
# 4- Further analysis and modeling may be needed to identify the factors that contribute to a team's success and predict their performance in future seasons.
#
# ## References and Future Work
#
# 1- With the 2023-2024 season coming soon, all these calculations can be changed quickly by alternating the seasons parameter.As we have already seen inside our analysis that some teams even go form winnng the league to join the botthom teams in next seasons.
#
# 2- The graphs aren't as good So there is a lot that can be improved as graph make things more clear and easy to understand.
#
# 3- At last I hope to make a win predictor to predict the current season winners of the each league using all teams involved in the current season by using their previous season stats .
